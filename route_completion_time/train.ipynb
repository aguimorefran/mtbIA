# %%
import pandas as pd
import numpy as np

# Load 
data = pd.read_csv('activity_data.csv')
data
# Out:
#     activity_id        date  distance_meters  elevation_gain  \
# 0   10333158490  2023-12-05          23352.9           565.6
# 1   10374952891  2023-12-13          18987.0           596.8
# 2   10388117261  2023-12-16          23681.8           763.8
# 3   10400469416  2023-12-18          18932.3           553.6
# 4   10415613275  2023-12-21          23733.3           703.0
# 5   10503740142  2024-01-06          22244.1           619.2
# 6   10544972626  2024-01-12          25110.8           167.6
# 7   10559280769  2024-01-14          33382.2           113.0
# 8   10570768646  2024-01-16          30933.5           122.2
# 9   10577006854  2024-01-17          32134.6           119.0
# 10  10592736697  2024-01-20          41008.4           217.6
# 11  10608342936  2024-01-22          39540.7           234.0
# 12  10621570886  2024-01-24          39547.4           191.4
# 13  10654826643  2024-01-29          38487.3           201.0
# ...

# %%
import pandas as pd
import numpy as np

# Load 
data = pd.read_csv('activity_data.csv')
data
# Out:
#    activity_id        date  distance  altitude_diff  elapsed_time time_of_day  \
# 0  11239581596  2024-04-22   14889.6          494.6        5040.0   afternoon
# 1  11247215041  2024-04-23   21675.9          602.0       92173.0   afternoon
# 2  11270218215  2024-04-26   36759.5          235.6      359916.0   afternoon
# 3  11277681242  2024-04-27   25808.7          149.2      443259.0   afternoon
# 4  11300707226  2024-04-30   27965.7          213.6      703548.0   afternoon
# 5  11309761769  2024-05-01   28380.8          207.8      789065.0   afternoon
# 6  11316120297  2024-05-02   30226.3          169.0      868428.0   afternoon
# 7  11331764055  2024-05-04   30174.8          211.6     1043702.0   afternoon
# 8  11346261507  2024-05-06   30221.9          187.6     1213573.0   afternoon
# 9  11362664941  2024-05-08   30814.5          248.0     1390321.0   afternoon
#
#    hour_of_day  atl_start  ctl_start  weight   watt_kg  temperature  \
# ...
